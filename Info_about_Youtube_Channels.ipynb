# %% [markdown]
# ### Our imports and open our file

# %%
import pandas as pd
import numpy as np 
df=pd.read_csv('topSubscribed.csv')

# %%
df
# Out:
#      Rank             Youtube Channel  Subscribers      Video Views  \
# 0       1                    T-Series  234,000,000  212,900,271,553
# 1       2              YouTube Movies  161,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448
# 3       4                   SET India  150,000,000  137,828,094,104
# 4       5                     MrBeast  128,000,000   21,549,128,785
# ..    ...                         ...          ...              ...
# 995   996                     XO TEAM   11,500,000   11,471,384,709
# 996   997         Nirahua Music World   11,500,000    5,997,717,755
# 997   998                     YtCrash   11,400,000        3,825,084
# 998   999                   Painzeiro   11,400,000    2,143,444,281
# 999  1000                   Oum Walid   11,400,000    2,480,064,722
#
#     Video Count          Category  Started
# 0        18,515             Music     2006
# 1             0  Film & Animation     2015
# ...

# %%
my_file=df.dropna()
my_file
# Out:
#      Rank             Youtube Channel  Subscribers      Video Views  \
# 0       1                    T-Series  234,000,000  212,900,271,553
# 1       2              YouTube Movies  161,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448
# 3       4                   SET India  150,000,000  137,828,094,104
# 4       5                     MrBeast  128,000,000   21,549,128,785
# ..    ...                         ...          ...              ...
# 995   996                     XO TEAM   11,500,000   11,471,384,709
# 996   997         Nirahua Music World   11,500,000    5,997,717,755
# 997   998                     YtCrash   11,400,000        3,825,084
# 998   999                   Painzeiro   11,400,000    2,143,444,281
# 999  1000                   Oum Walid   11,400,000    2,480,064,722
#
#     Video Count          Category  Started
# 0        18,515             Music     2006
# 1             0  Film & Animation     2015
# ...

# %% [markdown]
# ### Our info about dataset

# %%
my_file.info()
my_file.describe()
my_file.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1000 non-null   int64
#  1   Youtube Channel  1000 non-null   object
#  2   Subscribers      1000 non-null   object
#  3   Video Views      1000 non-null   object
#  4   Video Count      1000 non-null   object
#  5   Category         1000 non-null   object
#  6   Started          1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 62.5+ KB
# (1000, 7)

# %% [markdown]
# ### Top 5 Channels on Youtube with the most video views

# %%
top_5_channels_by_views=my_file.groupby('Youtube Channel').min().sort_values('Video Views').tail()
top_5_channels_by_views
# Out:
#                    Rank Subscribers     Video Views Video Count  \
# Youtube Channel
# Think Music India   785  13,000,000   9,958,947,026       4,452
# Sony SAB             17  76,400,000  91,117,292,875      63,390
# Apple               487  16,800,000     942,922,750         205
# Prajapati News      498  16,700,000     958,355,786       1,242
# Health Time         847  12,600,000     992,361,227       1,687
#
#                                Category  Started
# Youtube Channel
# Think Music India                 Music     2009
# Sony SAB                          Shows     2007
# Apple              Science & Technology     2005
# Prajapati News                   Comedy     2013
# Health Time               Howto & Style     2016

# %%
top_5_channels_by_views['Video Views'].max() #max video views
# Out:
# '992,361,227'

# %% [markdown]
# ### When the first Youtube Channel started

# %%
my_file.groupby('Youtube Channel').min().sort_values('Started').head(1)
# Out:
#                  Rank Subscribers    Video Views Video Count         Category  \
# Youtube Channel
# YouTube           100  35,200,000  2,980,922,779         620  News & Politics
#
#                  Started
# Youtube Channel
# YouTube             1970

# %% [markdown]
# ### Channel with the most subscribers

# %%
my_file
# Out:
#      Rank             Youtube Channel  Subscribers      Video Views  \
# 0       1                    T-Series  234,000,000  212,900,271,553
# 1       2              YouTube Movies  161,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448
# 3       4                   SET India  150,000,000  137,828,094,104
# 4       5                     MrBeast  128,000,000   21,549,128,785
# ..    ...                         ...          ...              ...
# 995   996                     XO TEAM   11,500,000   11,471,384,709
# 996   997         Nirahua Music World   11,500,000    5,997,717,755
# 997   998                     YtCrash   11,400,000        3,825,084
# 998   999                   Painzeiro   11,400,000    2,143,444,281
# 999  1000                   Oum Walid   11,400,000    2,480,064,722
#
#     Video Count          Category  Started
# 0        18,515             Music     2006
# 1             0  Film & Animation     2015
# ...

# %%
my_file.groupby("Subscribers").max().head()
# Out:
#              Rank    Youtube Channel     Video Views Video Count  \
# Subscribers
# 104,000,000     9        Like Nastya  87,202,935,675         754
# 106,000,000     8  ✿ Kids Diana Show  86,638,570,921       1,056
# 11,400,000   1000            YtCrash       3,825,084         946
# 11,500,000    997           설기양SULGI   9,569,061,994         788
# 11,600,000    980         Stray Kids   8,002,520,517         947
#
#                          Category  Started
# Subscribers
# 104,000,000        People & Blogs     2016
# 106,000,000        People & Blogs     2015
# 11,400,000         People & Blogs     2015
# 11,500,000                  Shows     2021
# 11,600,000   Science & Technology     2019

# %%
my_file.groupby('Youtube Channel').min().sort_values('Subscribers').plot(x='Subscribers',y='Rank')
